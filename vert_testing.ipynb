# %%
# %matplotlib inline
import xmitgcm
import xgcm
import xarray as xr
import matplotlib.pyplot as plt
from xlayers import finegrid, layers
from xlayers.core import layers_apply
import numpy as np

# %%
#load mitgcm output where \kappa_{redi}=50
datadir='tracers_mod_LGM/diffusion_50'
iters=range(54150000,54300000,150000)
prefixes=['tracer1','tracer2','layersDiags','dyn','gm']
dslayers=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid = xgcm.Grid(dslayers, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dslayers[name] for name in names]
all_tracers50 = xr.concat(all_tracer_list, dim='tracer')

# %%
#load mitgcm output where \kappa_{redi}=50
datadir='tracers_mod_LGM/diffusion_500'
iters=range(54150000,54300000,150000)
prefixes=['tracer1','tracer2']
ds500=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid = xgcm.Grid(dslayers, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dslayers[name] for name in names]
all_tracers500 = xr.concat(all_tracer_list, dim='tracer')

# %%
#load mitgcm output where \kappa_{redi}=5000
datadir='tracers_mod_LGM/diffusion_5000'
iters=range(54150000,54300000,150000)
prefixes=['tracer1','tracer2']
ds5000=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [ds5000[name] for name in names]
all_tracers5000 = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/mod_1000m'
iters=range(54150000,54200000,150000)
prefixes=['tracer1','tracer2']
dsvert=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid = xgcm.Grid(dsvert, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dsvert[name] for name in names]
all_tracers50vert = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/mod_2000m'
iters=range(54150000,54200000,150000)
prefixes=['tracer1','tracer2']
dsvert2000=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid = xgcm.Grid(dsvert2000, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dsvert2000[name] for name in names]
all_tracers50vert2 = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/LGM50'
iters=range(64800000,64850000,150000)
prefixes=['tracer1','layersDiags','dyn','tracer2','gm']#
dslayers1=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid2 = xgcm.Grid(dslayers1, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dslayers1[name] for name in names]
all_tracersLGM50 = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/LGM500'
iters=range(64800000,64850000,150000)
prefixes=['tracer1','tracer2']#
dslayers500=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid2 = xgcm.Grid(dslayers500, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dslayers500[name] for name in names]
all_tracersLGM500 = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/LGM5000'
iters=range(64800000,64850000,150000)
prefixes=['tracer1','tracer2']#
dsLGM5000=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid2 = xgcm.Grid(dsLGM5000, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dsLGM5000[name] for name in names]
all_tracersLGM5000 = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/LGM_1000m'
iters=range(64800000,64850000,150000)
prefixes=['tracer1','tracer2']
dsvert1=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid2 = xgcm.Grid(dsvert1, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dsvert1[name] for name in names]
all_tracersLGM1000m = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/LGM_2000m'
iters=range(64800000,64850000,150000)
prefixes=['tracer1','tracer2']
dsvertLGM2000=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
grid2 = xgcm.Grid(dsvertLGM2000, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dsvertLGM2000[name] for name in names]
all_tracersLGM2000m = xr.concat(all_tracer_list, dim='tracer')

# %%
datadir='tracers_mod_LGM/LGM500_kv5'
iters=range(64800000,64850000,150000)
prefixes=['tracer1','tracer2']
dskv5=xmitgcm.open_mdsdataset(datadir,prefix=prefixes,iters=iters)
gridkv5 = xgcm.Grid(dskv5, periodic=['X'])
names = ["TRAC01","TRAC02","TRAC03","TRAC04","TRAC05","TRAC06","TRAC07","TRAC08","TRAC09","TRAC10","TRAC11"]#list(ds.data_vars)
all_tracer_list = [dskv5[name] for name in names]
all_tracersLGMkv5 = xr.concat(all_tracer_list, dim='tracer')

# %%
layers_depth_pac1 = (grid.cumsum((dslayers.LaHs1RHO*dslayers.dxG).mean('time').where(dslayers.XC<140).sum('XC')/dslayers.dxG.where(dslayers.XC<140).sum('XC'), '1RHO',         
                                    boundary='fill').load())
layers_depth_atl1=(grid.cumsum((dslayers.LaHs1RHO*dslayers.dxG).mean('time').where(dslayers.XC>140).sum('XC')/dslayers.dxG.where(dslayers.XC>140).sum('XC'), '1RHO', 
                                  boundary='fill').load())
layers_depth1=grid.cumsum(dslayers.LaHs1RHO.mean('time').mean('XC'), '1RHO', boundary='fill').load()
layers_depth_atlmix1=xr.concat([layers_depth1[:,0:36], layers_depth_atl1[:,36:144]],'YG')
layers_depth_pacmix1=xr.concat([layers_depth1[:,0:36], layers_depth_pac1[:,36:144]],'YG')
layers_depth_pacmix1=layers_depth_pacmix1.where(xr.ufuncs.isfinite(layers_depth_pacmix1),0)
layers_depth_atlmix1=layers_depth_atlmix1.where(xr.ufuncs.isfinite(layers_depth_atlmix1),0)

# %%
layers_depth_pac2 = (grid2.cumsum((dslayers1.LaHs1RHO*dslayers1.dxG).mean('time').where(dslayers1.XC<140).sum('XC')/dslayers1.dxG.where(dslayers1.XC<140).sum('XC'), '1RHO',         
                                    boundary='fill').load())
layers_depth_atl2=(grid2.cumsum((dslayers1.LaHs1RHO*dslayers1.dxG).mean('time').where(dslayers1.XC>140).sum('XC')/dslayers1.dxG.where(dslayers1.XC>140).sum('XC'), '1RHO', 
                                  boundary='fill').load())
layers_depth2=grid2.cumsum(dslayers1.LaHs1RHO.mean('time').mean('XC'), '1RHO', boundary='fill').load()
layers_depth_atlmix2=xr.concat([layers_depth2[:,0:36], layers_depth_atl2[:,36:144]],'YG')
layers_depth_pacmix2=xr.concat([layers_depth2[:,0:36], layers_depth_pac2[:,36:144]],'YG')
layers_depth_pacmix2=layers_depth_pacmix2.where(xr.ufuncs.isfinite(layers_depth_pacmix2),0)
layers_depth_atlmix2=layers_depth_atlmix2.where(xr.ufuncs.isfinite(layers_depth_atlmix2),0)

# %%
ROC_pac1=grid.cumsum((dslayers.LaVH1RHO[:,:,:,0:139]*dslayers.dxG[:,0:139]).mean('time').sum('XC'),'1RHO',boundary='fill').load()
ROC_atl1=grid.cumsum((dslayers.LaVH1RHO[:,:,:,140:215]*dslayers.dxG[:,140:215]).mean('time').sum('XC'),'1RHO',boundary='fill').load()
ROC_tot1=grid.cumsum((dslayers.LaVH1RHO*dslayers.dxG).mean('time').sum('XC'),'1RHO',boundary='fill').load()
ROC_pac2=grid2.cumsum((dslayers1.LaVH1RHO[:,:,:,0:139]*dslayers1.dxG[:,0:139]).mean('time').sum('XC'),'1RHO',boundary='fill').load()
ROC_atl2=grid2.cumsum((dslayers1.LaVH1RHO[:,:,:,140:215]*dslayers1.dxG[:,140:215]).mean('time').sum('XC'),'1RHO',boundary='fill').load()
ROC_tot2=grid2.cumsum((dslayers1.LaVH1RHO*dslayers1.dxG).mean('time').sum('XC'),'1RHO',boundary='fill').load()

# %%
fig = plt.figure(figsize=(10,7))
plt.subplot(2, 2, 1)
b = ROC_atl1.copy()
b[:,0:35]=ROC_tot1[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix1
(b[:,:-1]/10**6).plot.contourf(x='YG',y='depth',vmin=-25,vmax=25,xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2), cmap='seismic',add_colorbar=False)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl1)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0.0085,0.4,0.2),colors='black',linewidths=2)
#layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0.0073,0.4,0.2),colors='black',linewidths=2)
plt.axvline(x=-35.5,color='yellow')

plt.subplot(2, 2, 3)
b = ROC_pac1.copy()
b[:,0:35]=ROC_tot1[:,0:35].copy()
b.coords['depth']=-layers_depth_pacmix1
(b[:,:-1]/10**6).plot.contourf(x='YG',y='depth',vmin=-25,vmax=25,xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),cmap='seismic',add_colorbar=False)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_pac1)
layer2D=layer2D.where(layer2D.YG<69)
layer2D.plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
layer2D.plot.contour(x='YG',y='depth',levels=np.arange(0.0085,0.4,0.2),colors='black',linewidths=2)
#layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0.0073,0.4,0.2),colors='black',linewidths=2)
plt.axvline(x=-35.5,color='yellow')

plt.subplot(2, 2, 2)
b = ROC_atl2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix2
(b[:,:-1]/10**6).plot.contourf(x='YG',y='depth',vmin=-25,vmax=25,xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2), cmap='seismic',add_colorbar=False)
layer2D,_=(xr.broadcast(-9.81*(dslayers1.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0.014,0.4,0.2),colors='black',linewidths=2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0.0107,0.4,0.2),colors='black',
                            linestyles='dashed',linewidths=2)
plt.axvline(x=-35.5,color='yellow')

plt.subplot(2, 2, 4)
b = ROC_pac2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_pacmix2
im=(b[:,:-1]/10**6).plot.contourf(x='YG',y='depth',vmin=-25,vmax=25,xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),cmap='seismic',add_colorbar=False)
layer2D,_=(xr.broadcast(-9.81*(dslayers1.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_pac2)
layer2D=layer2D.where(layer2D.YG<69)
layer2D.plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
layer2D.plot.contour(x='YG',y='depth',levels=np.arange(0.014,0.4,0.2),colors='black',linewidths=2)
layer2D.plot.contour(x='YG',y='depth',levels=np.arange(0.0107,0.4,0.2),colors='black',
                     linestyles='dashed',linewidths=2)
plt.axvline(x=-35.5,color='yellow')
fig.subplots_adjust(hspace=0.3, wspace=0.27,bottom = 0.35)
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.82, 0.35, 0.02, 0.53])
fig.colorbar(im, cax=cbar_ax)
#fig.savefig('ROC_modern_LGM.pdf', bbox_inches='tight')

# %%
#Eulerian tracers
fig = plt.figure(figsize=(15,8))
gs = fig.add_gridspec(2,5)
OT_atl=grid.cumsum((dslayers.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,140:].sum('XC'),'Z',boundary='extend',to='outer')
OT_tot=grid.cumsum((dslayers.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,:].sum('XC'),'Z',boundary='extend',to='outer')
OT_pac=grid.cumsum((dslayers.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,0:139].sum('XC'),'Z',boundary='extend',to='outer')
gm_atl=(dslayers.GM_PsiY*dslayers.dxG)[0,:,:,140:].sum('XC').rename({'Zl':'Zp1'})
gm_tot=(dslayers.GM_PsiY*dslayers.dxG)[0,:,:,:].sum('XC').rename({'Zl':'Zp1'})
gm_pac=(dslayers.GM_PsiY*dslayers.dxG)[0,:,:,0:139].sum('XC').rename({'Zl':'Zp1'})
Eul_atl=OT_atl.load()
Eul_atl[0:-1,:]=(OT_atl[0:-1,:]+gm_atl).rolling(YG=2).mean().load()
Eul_tot=OT_tot.load()
Eul_tot[0:-1,:]=(OT_tot[0:-1,:]+gm_tot).rolling(YG=2).mean().load()
Eul_pac=OT_pac.load()
Eul_pac[0:-1,:]=(OT_pac[0:-1,:]+gm_pac).rolling(YG=2).mean().load()
Eul_atl[:,0:35]=Eul_tot[:,0:35].load()
Eul_pac[:,0:35]=Eul_tot[:,0:35].load()
TRAC1_atl_uniform=(dslayers.TRAC01)[0,:,:,140:].mean('XC')
TRAC1_atl=(dsvert.TRAC01)[0,:,:,140:].mean('XC')
TRAC1_atl2=(dsvert2000.TRAC01)[0,:,:,140:].mean('XC')


fig.add_subplot(gs[0, 0])
kappaiso=np.fromfile('/swot/SUM01/spencer/vert_time/iso_1d_File0.bin',dtype='>f')
kappaiso2000=np.fromfile('/swot/SUM01/spencer/vert_2000/iso_1d_File2000.bin',dtype='>f')
plt.plot(50*np.ones(32),dsvertLGM2000.Z.values,linewidth=2)
plt.plot(kappaiso*500,dsvertLGM2000.Z.values,linewidth=2)
plt.legend(('Constant $\kappa_{redi}^{tr}$','Elevated $\kappa_{redi}^{tr}$ \n above 1000m'), prop={'size': 7.5})
plt.grid(True)
plt.xlabel('$\kappa_{redi}^{tr}$')
plt.ylabel('Depth (m)')
plt.ylim(-4000,0)
ax = plt.gca()
ax.text(-0.1, 1.15, 'a', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[0,1:3])
(TRAC1_atl-TRAC1_atl_uniform).plot(vmin=-1,vmax=1,rasterized=True,cmap='seismic',add_colorbar=False)
(Eul_atl/10**6).plot.contour(vmin=0,vmax=25,xlim=(-70,70),
                               ylim=(-4000,0),levels=np.arange(0,25.2,2),colors='white',linewidths=0.5)
(Eul_atl/10**6).plot.contour(vmin=-25,vmax=0,xlim=(-70,70),
                           ylim=(-4000,0),levels=np.arange(-25,0.2,2),colors='white', 
                               linestyles='dashed',linewidths=0.5)
ax = plt.gca()
ax.axvline(-36,color='yellow')
ax.axvline(-52.5,color='yellow')
ax.set_ylabel('depth')
ax.set_xlabel('')
ax.set_title(r'Modern ocean Atlantic' '\n' r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(1000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'b', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[1, 1:3])
(TRAC1_atl2-TRAC1_atl_uniform).plot(vmin=-1,vmax=1,rasterized=True,cmap='seismic',add_colorbar=False)
(Eul_atl/10**6).plot.contour(vmin=0,vmax=25,xlim=(-70,70),
                               ylim=(-4000,0),levels=np.arange(0,25.2,2),colors='white',linewidths=0.5)
(Eul_atl/10**6).plot.contour(vmin=-25,vmax=0,xlim=(-70,70),
                           ylim=(-4000,0),levels=np.arange(-25,0.2,2),colors='white', 
                               linestyles='dashed',linewidths=0.5)
ax = plt.gca()
ax.axvline(-36,color='yellow')
ax.axvline(-52.5,color='yellow')
ax.set_ylabel('depth')
ax.set_title(r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(2000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'e', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')


OT_atl=grid.cumsum((dslayers1.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,140:].sum('XC'),'Z',boundary='extend',to='outer')
OT_tot=grid.cumsum((dslayers1.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,:].sum('XC'),'Z',boundary='extend',to='outer')
OT_pac=grid.cumsum((dslayers1.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,0:139].sum('XC'),'Z',boundary='extend',to='outer')
gm_atl=(dslayers1.GM_PsiY*dslayers.dxG)[0,:,:,140:].sum('XC').rename({'Zl':'Zp1'})
gm_tot=(dslayers1.GM_PsiY*dslayers.dxG)[0,:,:,:].sum('XC').rename({'Zl':'Zp1'})
gm_pac=(dslayers1.GM_PsiY*dslayers.dxG)[0,:,:,0:139].sum('XC').rename({'Zl':'Zp1'})
Eul_atl=OT_atl.load()
Eul_atl[0:-1,:]=(OT_atl[0:-1,:]+gm_atl).rolling(YG=2).mean().load()
Eul_tot=OT_tot.load()
Eul_tot[0:-1,:]=(OT_tot[0:-1,:]+gm_tot).rolling(YG=2).mean().load()
Eul_pac=OT_pac.load()
Eul_pac[0:-1,:]=(OT_pac[0:-1,:]+gm_pac).rolling(YG=2).mean().load()
Eul_atl[:,0:35]=Eul_tot[:,0:35].load()
Eul_pac[:,0:35]=Eul_tot[:,0:35].load()
TRAC1_atlLGM_uniform=(dslayers1.TRAC01)[0,:,:,140:].mean('XC')
TRAC1_atlLGM=(dsvert1.TRAC01)[0,:,:,140:].mean('XC')
TRAC1_atl2LGM=(dsvertLGM2000.TRAC01)[0,:,:,140:].mean('XC')

fig.add_subplot(gs[1, 0])
kappaiso=np.fromfile('/swot/SUM01/spencer/vert_time/iso_1d_File0.bin',dtype='>f')
kappaiso2000=np.fromfile('/swot/SUM01/spencer/vert_2000/iso_1d_File2000.bin',dtype='>f')
plt.plot(50*np.ones(32),dsvertLGM2000.Z.values,linewidth=2)
plt.plot(kappaiso2000*500,dsvertLGM2000.Z.values,linewidth=2)
plt.legend(('Constant $\kappa_{redi}^{tr}$','Elevated $\kappa_{redi}^{tr}$ \n above 2000m'), prop={'size': 7.5})
plt.grid(True)
plt.xlabel('$\kappa_{redi}^{tr}$')
plt.ylabel('Depth (m)')
plt.ylim(-4000,0)
ax = plt.gca()
ax.text(-0.1, 1.15, 'd', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[0, 3:])
im2=(TRAC1_atlLGM-TRAC1_atlLGM_uniform).plot(vmin=-1,vmax=1,rasterized=True,cmap='seismic',add_colorbar=False)
(Eul_atl/10**6).plot.contour(vmin=0,vmax=25,xlim=(-70,70),
                               ylim=(-4000,0),levels=np.arange(0,25.2,2),colors='white',linewidths=0.5)
(Eul_atl/10**6).plot.contour(vmin=-25,vmax=0,xlim=(-70,70),
                           ylim=(-4000,0),levels=np.arange(-25,0.2,2),colors='white', 
                               linestyles='dashed',linewidths=0.5)
ax = plt.gca()
ax.axvline(-36,color='yellow')
ax.axvline(-52.5,color='yellow')
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title(r'Shoaled upper cell Atlantic' '\n' r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(1000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'c', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[1,3:])
im2=(TRAC1_atl2LGM-TRAC1_atlLGM_uniform).plot(vmin=-1,vmax=1,rasterized=True,cmap='seismic',add_colorbar=False)
(Eul_atl/10**6).plot.contour(vmin=0,vmax=25,xlim=(-70,70),
                               ylim=(-4000,0),levels=np.arange(0,25.2,2),colors='white',linewidths=0.5)
(Eul_atl/10**6).plot.contour(vmin=-25,vmax=0,xlim=(-70,70),
                           ylim=(-4000,0),levels=np.arange(-25,0.2,2),colors='white', 
                               linestyles='dashed',linewidths=0.5)
ax = plt.gca()
ax.axvline(-36,color='yellow')
ax.axvline(-52.5,color='yellow')
ax.set_ylabel('')
ax.set_title(r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(2000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'f', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.subplots_adjust(hspace=0.4, wspace=0.7,bottom = 0.35)
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.82, 0.35, 0.02, 0.53])
fig.colorbar(im2, cax=cbar_ax,label='$\Delta$ NAW fraction')
fig.savefig('isopycnal_mixing_1000m.pdf', bbox_inches='tight')

# %%
#Density tracers
buoy500=9.81*(2*10**-4*dslayers.THETA-7.4*10**-4*(dslayers.SALT-35))
baxis=(-9.81*(dslayers.layer_1RHO_bounds-35)/1035).values[::-1]

tracer_2000 = layers_apply(dsvert2000.TRAC01.mean('time'), buoy500.mean('time'), baxis, dslayers.drF, dslayers.drC, 10, 'Z', 'Tlev')
zeta_2000 = layers_apply(xr.ones_like(dslayers.TRAC01.mean('time')), buoy500.mean('time'), baxis, dslayers.drF, dslayers.drC, 10, 'Z', 'Tlev')

tracer_1000 = layers_apply(dsvert.TRAC01.mean('time'), buoy500.mean('time'), baxis, dslayers.drF, dslayers.drC, 10, 'Z', 'Tlev')
zeta_1000 = layers_apply(xr.ones_like(dslayers.TRAC01.mean('time')), buoy500.mean('time'), baxis, dslayers.drF, dslayers.drC, 10, 'Z', 'Tlev')

tracer_50 = layers_apply(dslayers.TRAC01.mean('time'), buoy500.mean('time'), baxis, dslayers.drF, dslayers.drC, 10, 'Z', 'Tlev')
zeta_50 = layers_apply(xr.ones_like(dslayers.TRAC01.mean('time')), buoy500.mean('time'), baxis, dslayers.drF, dslayers.drC, 10, 'Z', 'Tlev')

fig = plt.figure(figsize=(15,8))
gs = fig.add_gridspec(2,5)


fig.add_subplot(gs[0, 0])
kappaiso=np.fromfile('/swot/SUM01/spencer/vert_time/iso_1d_File0.bin',dtype='>f')
kappaiso2000=np.fromfile('/swot/SUM01/spencer/vert_2000/iso_1d_File2000.bin',dtype='>f')
plt.plot(50*np.ones(32),dsvertLGM2000.Z.values,linewidth=2)
plt.plot(kappaiso*500,dsvertLGM2000.Z.values,linewidth=2)
plt.legend(('Constant $\kappa_{redi}^{tr}$','Elevated $\kappa_{redi}^{tr}$ \n above 1000m'), prop={'size': 7.5})
plt.grid(True)
plt.xlabel('$\kappa_{redi}^{tr}$')
plt.ylabel('Depth (m)')
plt.ylim(-4000,0)
ax = plt.gca()
ax.text(-0.1, 1.15, 'a', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[0,1:3])
b = ROC_atl2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix2
c=(tracer_1000/zeta_1000-tracer_50/zeta_50)[:,140:-1,:].mean('XC').transpose('Tlev','YC')
thickness=zeta_50[:,140:-1,:].mean('XC').transpose('Tlev','YC')
c.coords['depth']=(-4000+(thickness).roll(Tlev=1,roll_coords=False).cumsum('Tlev'))

c.plot.contourf(x='YC',y='depth',cmap='seismic',levels=np.arange(-1,1,0.05),add_colorbar=False)
(b[:,:-1]/10**6).plot.contour(x='YG',y='depth',xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),colors='white',linewidths=0.5)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
plt.axvline(x=-35.5,color='yellow')
plt.xlabel('')
ax=plt.gca()
ax.set_title(r'Modern ocean Atlantic' '\n' r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(1000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'b', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[1, 1:3])
b = ROC_atl2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix2
c=(tracer_2000/zeta_2000-tracer_50/zeta_50)[:,140:-1,:].mean('XC').transpose('Tlev','YC')
thickness=zeta_50[:,140:-1,:].mean('XC').transpose('Tlev','YC')
c.coords['depth']=(-4000+(thickness).roll(Tlev=1,roll_coords=False).cumsum('Tlev'))

c.plot.contourf(x='YC',y='depth',cmap='seismic',levels=np.arange(-1,1,0.05),add_colorbar=False)
(b[:,:-1]/10**6).plot.contour(x='YG',y='depth',xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),colors='white',linewidths=0.5)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
plt.axvline(x=-35.5,color='yellow')
plt.xlabel('')
ax=plt.gca()
ax.set_title(r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(2000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'e', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

buoy500=9.81*(2*10**-4*dslayers1.THETA-7.4*10**-4*(dslayers1.SALT-35))
baxis=(-9.81*(dslayers1.layer_1RHO_bounds-35)/1035).values[::-1]

tracer_2000 = layers_apply(dsvertLGM2000.TRAC01.mean('time'), buoy500.mean('time'), baxis, dslayers1.drF, dslayers1.drC, 10, 'Z', 'Tlev')
zeta_2000 = layers_apply(xr.ones_like(dslayers.TRAC01.mean('time')), buoy500.mean('time'), baxis, dslayers1.drF, dslayers1.drC, 10, 'Z', 'Tlev')

tracer_1000 = layers_apply(dsvert1.TRAC01.mean('time'), buoy500.mean('time'), baxis, dslayers1.drF, dslayers1.drC, 10, 'Z', 'Tlev')
zeta_1000 = layers_apply(xr.ones_like(dslayers.TRAC01.mean('time')), buoy500.mean('time'), baxis, dslayers1.drF, dslayers1.drC, 10, 'Z', 'Tlev')

tracer_50 = layers_apply(dslayers1.TRAC01.mean('time'), buoy500.mean('time'), baxis, dslayers1.drF, dslayers1.drC, 10, 'Z', 'Tlev')
zeta_50 = layers_apply(xr.ones_like(dslayers1.TRAC01.mean('time')), buoy500.mean('time'), baxis, dslayers1.drF, dslayers1.drC, 10, 'Z', 'Tlev')

fig.add_subplot(gs[1, 0])
kappaiso=np.fromfile('/swot/SUM01/spencer/vert_time/iso_1d_File0.bin',dtype='>f')
kappaiso2000=np.fromfile('/swot/SUM01/spencer/vert_2000/iso_1d_File2000.bin',dtype='>f')
plt.plot(50*np.ones(32),dsvertLGM2000.Z.values,linewidth=2)
plt.plot(kappaiso2000*500,dsvertLGM2000.Z.values,linewidth=2)
plt.legend(('Constant $\kappa_{redi}^{tr}$','Elevated $\kappa_{redi}^{tr}$ \n above 2000m'), prop={'size': 7.5})
plt.grid(True)
plt.xlabel('$\kappa_{redi}^{tr}$')
plt.ylabel('Depth (m)')
plt.ylim(-4000,0)
ax = plt.gca()
ax.text(-0.1, 1.15, 'd', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[0, 3:])
b = ROC_atl2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix2
c=(tracer_1000/zeta_1000-tracer_50/zeta_50)[:,140:-1,:].mean('XC').transpose('Tlev','YC')
thickness=zeta_50[:,140:-1,:].mean('XC').transpose('Tlev','YC')
c.coords['depth']=(-4000+(thickness).roll(Tlev=1,roll_coords=False).cumsum('Tlev'))

c.plot.contourf(x='YC',y='depth',cmap='seismic',levels=np.arange(-1,1,0.05),add_colorbar=False)
(b[:,:-1]/10**6).plot.contour(x='YG',y='depth',xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),colors='white',linewidths=0.5)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
plt.axvline(x=-35.5,color='yellow')
plt.xlabel('')
ax=plt.gca()
ax.set_title(r'Shoaled upper cell Atlantic' '\n' r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(1000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'c', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.add_subplot(gs[1,3:])
b = ROC_atl2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix2
c=(tracer_2000/zeta_2000-tracer_50/zeta_50)[:,140:-1,:].mean('XC').transpose('Tlev','YC')
thickness=zeta_50[:,140:-1,:].mean('XC').transpose('Tlev','YC')
c.coords['depth']=(-4000+(thickness).roll(Tlev=1,roll_coords=False).cumsum('Tlev'))

c.plot.contourf(x='YC',y='depth',cmap='seismic',levels=np.arange(-1,1,0.05),add_colorbar=False)
(b[:,:-1]/10**6).plot.contour(x='YG',y='depth',xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),colors='white',linewidths=0.5)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
plt.axvline(x=-35.5,color='yellow')
plt.xlabel('')
ax=plt.gca()
ax.set_title(r'$[NAW](\kappa_{redi}^{tr}=\kappa_{pr}(2000m))-[NAW](\kappa_{redi}^{tr}=50m^2/s$)')
ax.text(-0.1, 1.15, 'f', transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

fig.subplots_adjust(hspace=0.4, wspace=0.7,bottom = 0.35)
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.82, 0.35, 0.02, 0.53])
fig.colorbar(im2, cax=cbar_ax,label='$\Delta$ NAW fraction')
fig.savefig('isopycnal_density_1000m.pdf', bbox_inches='tight')
# Out:
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
buoy500=9.81*(2*10**-4*dslayers1.THETA-7.4*10**-4*(dslayers1.SALT-35))
baxis=(-9.81*(dslayers1.layer_1RHO_bounds-35)/1035).values[::-1]

trac1=all_tracersLGMkv5.expand_dims('case')
tracer_500 = layers_apply(dskv5.TRAC01.mean('time'), buoy500.mean('time'), baxis, dskv5.drF, dskv5.drC, 10, 'Z', 'Tlev')
zeta_500 = layers_apply(xr.ones_like(dskv5.TRAC01.mean('time')), buoy500.mean('time'), baxis, dskv5.drF, dskv5.drC, 10, 'Z', 'Tlev')



fig = plt.figure(figsize=(4.4,7))
plt.subplot(2, 1, 1)
b = ROC_atl2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_atlmix2
c=(tracer_500/zeta_500)[:,140:-1,:].mean('XC').transpose('Tlev','YC')
thickness=zeta_500[:,140:-1,:].mean('XC').transpose('Tlev','YC')
c.coords['depth']=(-4000+(thickness).roll(Tlev=1,roll_coords=False).cumsum('Tlev'))

c.plot.contourf(x='YC',y='depth',cmap='viridis',levels=np.arange(0,1,0.05),add_colorbar=False)
(b[:,:-1]/10**6).plot.contour(x='YG',y='depth',xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),colors='white',linewidths=0.5)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_atl2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
plt.axvline(x=-35.5,color='yellow')
plt.xlabel('')
plt.title(r'LGM ocean, $\kappa_v^{tr}=2 \times 10^{-5} m^2/s$')
ax=plt.gca()
ax.text(1, 0.13, 'Atlantic', transform=ax.transAxes,
      fontsize=14, fontweight='bold', va='top', ha='right',bbox=dict(facecolor='white', alpha=1,ec="None"))

plt.subplot(2, 1, 2)
b = ROC_pac2.copy()
b[:,0:35]=ROC_tot2[:,0:35].copy()
b.coords['depth']=-layers_depth_pacmix2
c=(tracer_500/zeta_500)[:,:140,:].mean('XC').transpose('Tlev','YC')
thickness=zeta_500[:,:140,:].mean('XC').transpose('Tlev','YC')
c.coords['depth']=(-4000+(thickness).roll(Tlev=1,roll_coords=False).cumsum('Tlev'))

im2 = c.plot.contourf(x='YC',y='depth',cmap='viridis',levels=np.arange(0,1,0.05),add_colorbar=False)
(b[:,:-1]/10**6).plot.contour(x='YG',y='depth',xlim=(-70,70),ylim=(-4000,0),levels=np.arange(-25,25.2,2),colors='white',linewidths=0.5)
layer2D,_=(xr.broadcast(-9.81*(dslayers.layer_1RHO_bounds-35)/1035, dslayers.YG))
layer2D.coords['depth']=(-layers_depth_pac2)
layer2D[:,:-1].plot.contour(x='YG',y='depth',levels=np.arange(0,0.04,0.002),colors='black',linewidths=0.5)
plt.axvline(x=-35.5,color='yellow')
plt.xlabel('Latitude')
ax=plt.gca()
ax.text(1, 0.13, 'Pacific', transform=ax.transAxes,
      fontsize=14, fontweight='bold', va='top', ha='right',bbox=dict(facecolor='white', alpha=1,ec="None"))
fig.subplots_adjust(hspace=0.3, wspace=0.27,bottom = 0.35)
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.82, 0.35, 0.04, 0.53])
cbar=fig.colorbar(im2, cax=cbar_ax,label='NADW fraction')
fig.colorbar(im2, cax=cbar_ax)
fig.savefig('tracers_modern_LGMkv5.pdf', bbox_inches='tight')
# Out:
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# Warning: theta_in may not be monotonically ascending/descending
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/spencerj/.conda/envs/pangeo1/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
#tracers kv5 in depth space
fig = plt.figure(figsize=(4.4,7))
plt.subplot(2, 1, 1)
OT_atl=grid.cumsum((dslayers1.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,140:].sum('XC'),'Z',boundary='extend',to='outer')
OT_tot=grid.cumsum((dslayers1.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,:].sum('XC'),'Z',boundary='extend',to='outer')
OT_pac=grid.cumsum((dslayers1.VVEL*dslayers.drF*dslayers.dxG)[0,:,:,0:139].sum('XC'),'Z',boundary='extend',to='outer')
gm_atl=(dslayers1.GM_PsiY*dslayers.dxG)[0,:,:,140:].sum('XC').rename({'Zl':'Zp1'})
gm_tot=(dslayers1.GM_PsiY*dslayers.dxG)[0,:,:,:].sum('XC').rename({'Zl':'Zp1'})
gm_pac=(dslayers1.GM_PsiY*dslayers.dxG)[0,:,:,0:139].sum('XC').rename({'Zl':'Zp1'})
Eul_atl=OT_atl.load()
Eul_atl[0:-1,:]=(OT_atl[0:-1,:]+gm_atl).rolling(YG=2).mean().load()
Eul_tot=OT_tot.load()
Eul_tot[0:-1,:]=(OT_tot[0:-1,:]+gm_tot).rolling(YG=2).mean().load()
Eul_pac=OT_pac.load()
Eul_pac[0:-1,:]=(OT_pac[0:-1,:]+gm_pac).rolling(YG=2).mean().load()
Eul_atl[:,0:35]=Eul_tot[:,0:35].load()
Eul_pac[:,0:35]=Eul_tot[:,0:35].load()
TRAC1_atl=(dskv5.TRAC01)[0,:,:,140:].mean('XC')
TRAC1_atl.plot(vmin=0,vmax=1,rasterized=True,cmap='viridis',add_colorbar=False)
(Eul_atl/10**6).plot.contour(vmin=0,vmax=25,xlim=(-70,70),
                               ylim=(-4000,0),levels=np.arange(0,25.2,2),colors='white',linewidths=0.5)
(Eul_atl/10**6).plot.contour(vmin=-25,vmax=0,xlim=(-70,70),
                           ylim=(-4000,0),levels=np.arange(-25,0.2,2),colors='white', 
                               linestyles='dashed',linewidths=0.5)
ax = plt.gca()
ax.axvline(-36,color='yellow')
ax.axvline(-52.5,color='yellow')
ax.set_ylabel('depth')
ax.set_xlabel('')
ax.set_title(r'Shoaled upper cell, $\kappa_v^{tr}=2\times 10^{-5} m^2/s$')
ax.text(1, 0.13, 'Atlantic', transform=ax.transAxes,
      fontsize=14, fontweight='bold', va='top', ha='right',bbox=dict(facecolor='white', alpha=1,ec="None"))


plt.subplot(2, 1, 2)
TRAC1_atl2=(dskv5.TRAC01)[0,:,:,:140].mean('XC')
im=TRAC1_atl2.plot(vmin=0,vmax=1,rasterized=True,cmap='viridis',add_colorbar=False)
(Eul_pac/10**6).plot.contour(vmin=0,vmax=25,xlim=(-70,70),
                               ylim=(-4000,0),levels=np.arange(0,25.2,2),colors='white',linewidths=0.5)
(Eul_pac/10**6).plot.contour(vmin=-25,vmax=0,xlim=(-70,70),
                           ylim=(-4000,0),levels=np.arange(-25,0.2,2),colors='white', 
                               linestyles='dashed',linewidths=0.5)
ax = plt.gca()
ax.axvline(-36,color='yellow')
ax.axvline(-52.5,color='yellow')
ax.set_ylabel('depth')
ax.set_xlabel('Latitude')
ax.text(1, 0.13, 'Pacific', transform=ax.transAxes,
      fontsize=14, fontweight='bold', va='top', ha='right',bbox=dict(facecolor='white', alpha=1,ec="None"))
ax.set_title('')





fig.subplots_adjust(hspace=0.3, wspace=0.27,bottom = 0.35)
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.82, 0.35, 0.04, 0.53])
cbar=fig.colorbar(im, cax=cbar_ax,label='NAW fraction')

fig.savefig('tracers_kv5_depth.pdf', bbox_inches='tight')

# %%
all_tracer=xr.concat([all_tracers50, all_tracers500, all_tracers5000, all_tracersLGM50, all_tracersLGM500, all_tracersLGM5000, all_tracers50vert, all_tracers50vert2, all_tracersLGM1000m, all_tracersLGM2000m],'case')
new_tracer=all_tracer.isel(tracer=slice(0,4))
AABW=(all_tracer.isel(tracer=8)+all_tracer.isel(tracer=9)).expand_dims('tracer')
MW=(all_tracer.isel(tracer=6)+all_tracer.isel(tracer=7)).expand_dims('tracer')
CW=(all_tracer.isel(tracer=4)+all_tracer.isel(tracer=5)).expand_dims('tracer')
new_tracerset=xr.concat([new_tracer,CW,MW,AABW],dim='tracer')

new_tracerset = xr.concat([new_tracerset.isel(case=slice(0,5)),
                           xr.zeros_like(new_tracerset.isel(case=1)).expand_dims('case'),
                           new_tracerset.isel(case=slice(5,10))],dim='case')


deepPac= ((new_tracerset.mean('time') * dslayers.drF *dslayers.rA).isel(tracer=slice(0,10))
          .where(dslayers.XC>140).where(dslayers.Z<-2000).where(dslayers.YC<0).where(dslayers.YC>-30)
         ).sum(dim=['XC','YC','Z'])/((dslayers.drF *dslayers.rA.where(dslayers.XC>140).where(dslayers.Z<-2000)
                                      .where(dslayers.YC<0).where(dslayers.YC>-30)).sum(dim=['XC','YC','Z']))
deepPac['tracer']=["NAW","NPW","LLAW","LLPW","NSOW","SOW","AABW"]
deepPac['case']=['50','500','5000','SUC aaa 50','SUC aaa 500','SUC','SUC aaa 5000','5000 above 1000m','5000 above 2000m','SUC above 1000m','SUC above 2000m']
seriesPac = deepPac.to_series()
series2Pac=seriesPac.reset_index(name='tracerint').groupby(['tracer','case'])['tracerint'].sum().unstack('tracer').fillna(0)
#series2
cmap = plt.cm.get_cmap('tab20')
series2Pac.plot(kind='bar',stacked='True', edgecolor='black',color=[cmap(0),cmap(7),cmap(5),cmap(6),cmap(4),cmap(9),cmap(19)])
handles, labels = plt.gca().get_legend_handles_labels()
order = [6,5,4,3,2,1,0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],title='Water-mass tracer')
plt.grid(True)
plt.xlim(-6, 10.5)
plt.ylabel('Tracer concentration')
ax=plt.gca()
ax.set_xticklabels((r'$\kappa^{redi}_{tr}=50$', r'$\kappa^{redi}_{tr}=500$', r'$\kappa^{redi}_{tr}=5000$',
                    r'Elevated $\kappa^{redi}_{tr}$ above 1000m',r'Elevated $\kappa^{redi}_{tr}$ above 2000m','', 
                    r'$\kappa^{redi}_{tr}=50$', r'$\kappa^{redi}_{tr}=500$', r'$\kappa^{redi}_{tr}=5000$', 
                r'Elevated $\kappa^{redi}_{tr}$ above 1000m',r'Elevated $\kappa^{redi}_{tr}$ above 2000m'));
plt.text(0.6, 1.07, 'Modern', transform=ax.transAxes,
      fontsize=14, fontweight='bold', va='top', ha='right',bbox=dict(facecolor='None',ec="None"))
plt.text(0.9, 1.07, 'SUC', transform=ax.transAxes,
      fontsize=14, fontweight='bold', va='top', ha='right',bbox=dict(facecolor='None',ec="None"))
fig=plt.gcf()
fig.savefig('summary_figure.pdf', bbox_inches='tight')
